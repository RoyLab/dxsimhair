# %%
# %run test.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# D:\Codes\HairSimulation\src\Scripts\test.py in <module>()
#       2
#       3 a = 3
# ----> 4 b == a
#
# NameError: name 'b' is not defined

# %%
reload(pymetis_example)

# %%
import pymetis_example

# %%
pymetis_example.test_tet_mesh()
